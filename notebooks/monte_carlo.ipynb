# %% [markdown]
# $$
# H = -J\sum_{<ij>}cos(\phi_i - \phi_j) - \sum_{j} h_jcos(\phi_j-\theta_j) + \eta_j(t)
# $$

# %%
import sys
sys.path.append('../src/')
from xpcs import *
from sims import *
from autocorrelations import *

import numpy as np
import matplotlib.pyplot as plt
from cmcrameri import cm

# %matplotlib notebook

# %%
size = 256

phi = np.pi*(2*np.random.rand(size,size)-1)

# %%
fig,ax = plt.subplots()

ax.imshow(phi,'nipy_spectral')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pel = np.load('pel.npy')

# %%
fig, ax = plt.subplots(1,3)

for i,p in enumerate(pel):
    ax[i].imshow(p, cmap=cm.lipari)
    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def monte_carlo(phi0,pel):
J = 1
Temps = np.range(0,5*J,100).T    
sweeps_per_temp = phi0.shape[1]**2
    for T in Temps:
        for sweep in range(sweeps_per_temp):
