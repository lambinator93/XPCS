# %%
import sys
sys.path.append('../src/')
from xpcs import *
from sims import *
from autocorrelations import *
import cv2
from scipy.special import erfinv
import pyopencl as cl
from pathlib import Path
import matplotlib.cm as cm
import json
import matplotlib.ticker as ticker

# %matplotlib notebook

# %%
figure_path = '/Users/eriklamb/Documents/Publications/NPS_Petra/Figures/'

# %%
def energy_1d(phi,a=1,b=1,d=1):
    return phi**6-a*phi**4+b*phi**2+d*phi**3

# %%
fig, ax = plt.subplots()

phis = np.linspace(-1.3,1.4,100)
ax.plot(phis,energy_1d(phis,2,1,-0.2),'b')
ax.set_ylabel('E',fontsize=18)
ax.set_xlabel('$\\phi$',fontsize=18)
#ax.set_axis_off()
plt.xticks([])
plt.yticks([])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([], [])

# %%
fig.savefig(figure_path+"three_states_favored.pdf",format="pdf",bbox_inches="tight")
