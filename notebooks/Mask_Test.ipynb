# %%
import sys
sys.path.append('../src/')
from xpcs import *
from sims import *
from autocorrelations import *
import cv2
from scipy.special import erfinv
import pyopencl as cl
from pathlib import Path
import json
from scipy.fft import fft, ifft, fftfreq
from scipy.ndimage import rotate


# %matplotlib notebook

# %%
height, width = 1300, 750
# Create a grid of coordinates
y, x = np.ogrid[:height, :width]

center = (height // 2, width // 2)  # Center of the image


angle_from_center = np.arctan2(y - center[0], x - center[1])  # Angle in radians


angle_from_center = (angle_from_center + 2 * np.pi) % (2 * np.pi) # Normalize to [0, 2*pi)

num_slices = 8
slice_span = 2*np.pi/num_slices 

j=0
start_angle = -angle_width / 2 + j * angle_width
end_angle = start_angle + angle_width

print(start_angle)
print(end_angle)
# Out:
# -0.39269908169872414
# 0.39269908169872414

# %%
fig,ax = plt.subplots()

j = 0
if j == 0:
    slice_mask1 = (angle_from_center >= 2*np.pi+start_angle) | (angle_from_center < end_angle) 

im=ax.imshow(slice_mask1,origin="lower",cmap='plasma')
fig.colorbar(im, ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
