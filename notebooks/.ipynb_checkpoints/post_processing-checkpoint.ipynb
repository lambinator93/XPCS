# %%
import sys
sys.path.append('../src/')
from xpcs import *
from sims import *
from autocorrelations import *
import cv2
from scipy.special import erfinv
from scipy.special import erf
import pyopencl as cl

# %matplotlib notebook

plt.close()

# %% [markdown]
# # User Defined Parameters

# %%
### Beamline Parameters ###
Beamline = 'P10' #P10 or 8IDE
Geometry = 'Horizontal' #Horizontal or Vertical
Compound = 'NPS'

### Analysis Parameters ###


### File Parameters ###
Particle = 2 #2,3
Temperatures = np.array([298,305,315,325,345,365,385,405,350])
Scans = np.array([219,334,416,552,579,709,779,796,868]) # P3:[239,356
Attenuation = 20

Temperature = Temperatures[0]
Scan = Scans[0]
#Crop Size
#number of standard deviations from peak
Xv = 5
Xh = 5

# %% [markdown]
# # File Paths

# %%
paths_list = []

for Temperature, Scan in zip(Temperatures,Scans):
    
    if Compound == 'NBH':
        results_path = f'/Volumes/Eriks_4TB/APSU_1004574_shpyrko202411/A{Scan}_NaBH_att0000{Attenuation}_{Temperature}K_001/result/'
    if Compound == 'NPS':
        results_path = f'/Users/eriklamb/Documents/Data/PETRA/PETRA_P10_November2023/Beamtime_11017686/XPCS_Scans/Particle_{Particle}/{Temperature}K/NPS_01_00{Scan}/result/'

    #Check that path exists
    if not os.path.exists(results_path):
        print(f"Directory '{results_path}' Does Not Exist!")

    #Load File Names
    file_list = np.sort(os.listdir(results_path)).tolist()

    #Remove first element if it's DS_Store
    if file_list[0] == '.DS_Store':
        file_list.remove(file_list[0])

    #Removes strange file that occurs if you edit batchinfo
    if file_list[0][0:2] == '._':
        file_list.remove(file_list[0])

    #for f in file_list:
        #print(f)

    #Retrieve number of files
    num_files = len(file_list)
    
    paths_list.append(results_path+file_list[-1])
    
#print(paths_list)

# %% [markdown]
# # Load Data

# %%
# first load

results = h5py.File(file, 'r')

dQ = results['XPCS/dQ'][:]
taus = results['XPCS/taus'][:]
taus_err = results['XPCS/taus_err'][:]
betas = results['XPCS/betas'][:]
betas_err = results['XPCS/betas_err'][:]
As = results['XPCS/As'][:]
As_err = results['XPCS/As_err'][:]
Cs = results['XPCS/Cs'][:]
Cs_err = results['XPCS/Cs_err'][:]
T = np.array([file[-47:-44]])


first_load = True

for file in paths_list:
    results = h5py.File(file, 'r')
    
    dQ = np.append(dQ,[results['XPCS/dQ'][:]],axis=0)
        
    taus = np.append(taus,results['XPCS/taus'][:],axis=0)
    taus_err = np.append(taus_err,results['XPCS/taus_err'][:],axis=0)
    
    betas = np.append(betas,results['XPCS/betas'][:],axis=0)
    betas_err = np.append(betas_err,results['XPCS/betas_err'][:],axis=0)
    
    As = np.append(As,results['XPCS/As'][:],axis=0)
    As_err = np.append(As_err,results['XPCS/As_err'][:],axis=0)
    
    Cs = np.append(Cs,results['XPCS/Cs'][:],axis=0)
    Cs_err = np.append(Cs_err,results['XPCS/Cs_err'][:],axis=0)
    
    T = np.append(T,file[-47:-44])
    
    if first_load == True:
        dQ = dQ.reshape((1,dQ.shape[0]))
    
        first_load=False
    results.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 18
#      15 for file in paths_list:
#      16     results = h5py.File(file, 'r')
# ---> 18     dQ = np.append(dQ,[results['XPCS/dQ'][:]],axis=0)
#      20     taus = np.append(taus,results['XPCS/taus'][:],axis=0)
#      21     taus_err = np.append(taus_err,results['XPCS/taus_err'][:],axis=0)
#
# File ~/miniforge3/envs/xpcs/lib/python3.12/site-packages/numpy/lib/function_base.py:5618, in append(arr, values, axis)
#    5616     values = ravel(values)
#    5617     axis = arr.ndim-1
# -> 5618 return concatenate((arr, values), axis=axis)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
dQ.
# Out:
# (162,)

# %% [markdown]
# # Plotting

# %%
fig, ax = plt.subplots()


ax.semilogy(T,taus[:,0])
ax.set_ylabel('$\\tau$ (s)')
ax.set_xlabel('Temperature (K)')


    #axs[0].errorbar(dQ,taus, yerr=taus_err,fmt='none',ecolor='b',capsize=2)
    #axs[0].semilogy(dQ,taus,'-*',label=file[-47:-44]+'K')
    #axs[0].legend(loc = 'center right')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 4
#       1 fig, ax = plt.subplots()
# ----> 4 ax.semilogy(T,taus[:,0])
#       5 ax.set_ylabel('$\\tau$ (s)')
#       6 ax.set_xlabel('Temperature (K)')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
