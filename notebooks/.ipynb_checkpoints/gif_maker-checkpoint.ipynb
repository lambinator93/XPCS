# %%
import sys
sys.path.append('../src/')
from xpcs import *
from sims import *
from autocorrelations import *
import cv2
from scipy.special import erfinv
import pyopencl as cl

# %matplotlib notebook

# %%
data_path = '/Volumes/Eriks_4TB/APSU_1004574_shpyrko_2025_1/data/'

file_path = 'A124_Oc3_att001000_100K_001'

# %%
#Check that path exists
if not os.path.exists(data_path+file_path):
    print(f"Directory '{data_path+file_path}' Does Not Exist!")

#Load File Names
file_list = np.sort(os.listdir(data_path+file_path)).tolist()

#Remove first element if it's DS_Store
if file_list[0] == '.DS_Store':
    file_list.remove(file_list[0])
    
for f in file_list:
    print(f)
 
#Retrieve number of files
num_files = len(file_list)
# Out:
# A136_12c4_att000000_300K_001.h5
# A136_12c4_att000000_300K_001_0001-0117.batchinfo
# A136_12c4_att000000_300K_001_metadata.hdf

# %%
def print_h5_item(item, indent=''):
    """
    Recursively print the contents of an h5py group or dataset.
    
    Args:
    - item: The h5py group or dataset to print.
    - indent: A string of spaces used to indent nested items for better readability.
    """
    
    if isinstance(item, h5py.Group):  # Check if item is a group
        for key, subitem in item.items():
            print(f"{indent}/{key}")  # Print group name
            print_h5_item(subitem, indent + '    ')  # Recursively print contents of the group with additional indentation
    elif isinstance(item, h5py.Dataset):  # Check if item is a dataset
        print(f"{indent}[Dataset] Shape: {item.shape}, Type: {item.dtype}")
        # To print actual data, uncomment the line below. Be cautious with large datasets.
        # print(item[:])
        
        
def make_detector_movie(imgs, scan_var, fig, ax, filename, clims, fps,period=1):
    # Makes an animation of the detector images stored in `imgs`.
    # `fig` and `ax` are the Figure and Axes objects used to plot each movie frame
    # `filename` is the name of the output .gif file
    # `clims` is the colormap range
    # `fps` is the frame rate (frames per second) of the movie
    Nt = imgs.shape[0]
    im = ax.imshow(imgs[0,:,:], cmap='nipy_spectral',norm=LogNorm(vmin=clims[0], vmax=clims[1]))
    
    def func(ii):
        im.set_data(imgs[ii,:,:])
        ax.set_title(f'Time = {period*scan_var[ii-1]:.2f} seconds',fontsize = 24)
        return im
    
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    anim = FuncAnimation(fig, func, frames=range(1,Nt))
    anim.save(filename + '_short_2.gif', writer=PillowWriter(fps=fps))

# %%
#Set the file name
filename = data_path+file_path+file_list[0]
print(filename)

with h5py.File(filename, 'r') as f:
    print_h5_item(f)
# Out:
# /Volumes/Eriks_4TB/APSU_1004574_shpyrko_2025_1/data/A136_12c4_att000000_300K_001/A136_12c4_att000000_300K_001.h5
# /entry
#     /data
#         /data
#             [Dataset] Shape: (195, 2162, 2068), Type: uint32
#     /instrument
#         /NDAttributes
#             /BeamCenterX
#                 [Dataset] Shape: (195,), Type: float32
#             /BeamCenterY
#                 [Dataset] Shape: (195,), Type: float32
#             /CountTime
#                 [Dataset] Shape: (195,), Type: float64
#             /CountrateCutoff
#                 [Dataset] Shape: (195,), Type: float32
#             /DetectorDescription
#                 [Dataset] Shape: (195,), Type: |S256
#             /DetectorDistance
#                 [Dataset] Shape: (195,), Type: float32
#             /DetectorSerialNumber
#                 [Dataset] Shape: (195,), Type: |S256
#             /DetectorSoftwareVersion
#                 [Dataset] Shape: (195,), Type: float32
#             /FrameTime
#                 [Dataset] Shape: (195,), Type: float64
#             /NDArrayEpicsTSSec
#                 [Dataset] Shape: (195,), Type: uint32
#             /NDArrayEpicsTSnSec
#                 [Dataset] Shape: (195,), Type: uint32
#             /NDArrayTimeStamp
#                 [Dataset] Shape: (195,), Type: float64
#             /NDArrayUniqueId
#                 [Dataset] Shape: (195,), Type: int32
#             /OmegaIncrement
#                 [Dataset] Shape: (195,), Type: float32
#             /OmegaStart
#                 [Dataset] Shape: (195,), Type: float32
#             /PixelMaskApplied
#                 [Dataset] Shape: (195,), Type: float32
#             /SensorMaterial
#                 [Dataset] Shape: (195,), Type: float32
#             /SensorThickness
#                 [Dataset] Shape: (195,), Type: float32
#             /Wavelength
#                 [Dataset] Shape: (195,), Type: float64
#             /XPixelSize
#                 [Dataset] Shape: (195,), Type: float32
#             /YPixelSize
#                 [Dataset] Shape: (195,), Type: float32
#         /detector
#             /NDAttributes
#             /data
#                 [Dataset] Shape: (195, 2162, 2068), Type: uint32
#         /performance
#             /timestamp
#                 [Dataset] Shape: (0, 5), Type: float64

# %%
#Set ROI and Set Hot-Pixels to Zero
roi = [645,1155,265,-1]

det = np.array(h5py.File(filename, 'r')['entry/data/data/'])[:]
time = np.array(h5py.File(filename, 'r')['entry/instrument/NDAttributes/NDArrayTimeStamp'])#-time[0] #Time of each frame
det[det>10000] = 0 
#det[det<=1] = 0 

fig, ax = plt.subplots()
ax.imshow(np.sum(det[0:1,:,:],axis=0)+1,cmap='nipy_spectral',norm=LogNorm(vmin=1, vmax=5000))

ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
time = time-time[0]

# %%
time
# Out:
# array([  0.        ,   0.99538898,   2.00051951,   2.99592638,
#          4.00119734,   4.9965899 ,   5.99193859,   6.99727249,
#          7.99246097,   8.9981823 ,   9.99310589,  10.99855542,
#         11.99375558,  12.99910998,  13.99442434,  14.99956489,
#         15.99507594,  17.00048304,  17.99573255,  19.00102448,
#         19.99633527,  20.99158216,  21.99680996,  22.99201107,
#         23.9974122 ,  24.992805  ,  25.99816394,  26.99351621,
#         27.99891639,  28.99420667,  29.99946213,  30.99479294,
#         32.00007057,  32.99539161,  34.00062561,  34.99604988,
#         36.00138855,  36.9966929 ,  38.0019896 ,  38.99734569,
#         39.99262094,  40.99794269,  41.99328947,  42.99857807,
#         43.99376631,  44.99926138,  45.99456191,  46.99982452,
#         47.99524903,  49.00054121,  49.99583936,  51.00126052,
#         51.9963429 ,  52.99187922,  53.99724412,  54.99258566,
#         55.99791527,  56.99311781,  57.99839115,  58.99484372,
#         59.9991045 ,  60.9947505 ,  62.00009632,  62.99539208,
#         64.00075006,  64.99627137,  66.00143814,  66.99657536,
#         67.99204063,  68.99734497,  69.99266243,  70.99800062,
#         71.99329829,  72.99855995,  73.99389911,  74.99917912,
#         75.9944489 ,  76.99962807,  77.99510098,  79.00026178,
#         79.99575686,  81.00095296,  81.99635243,  83.00145793,
#         83.99687552,  85.00227928,  85.99755359,  86.99284482,
#         87.99797344,  88.99337173,  89.99856639,  90.99395776,
#         91.99939013,  92.99471569,  94.00000954,  94.99527669,
#         96.00066638,  96.99601793,  97.99109793,  98.99653912,
#         99.99188495, 100.99705505, 102.00238109, 102.99789691,
#        103.99295139, 104.99838877, 105.99373984, 106.99900603,
#        107.99435616, 108.99965525, 109.99500346, 111.00028825,
#        111.99562955, 113.00087523, 113.99628711, 115.00153327,
#        116.05720901, 133.39605713, 134.39158702, 135.39688611,
#        136.39220285, 137.39754248, 138.39265466, 139.38791275,
#        140.39323902, 141.38881326, 142.39412761, 143.38943386,
#        144.39474225, 145.3900485 , 146.39535809, 147.39065671,
#        148.39578342, 149.39132428, 150.3966589 , 151.39173388,
#        152.38725281, 153.39236832, 154.39768672, 155.39326692,
#        156.3884933 , 157.39358497, 158.38891935, 159.39421535,
#        160.38954139, 161.39511037, 162.39013648, 163.39551783,
#        164.39082098, 165.39611959, 166.39170527, 167.3968029 ,
#        168.39226747, 169.39758945, 170.39295602, 171.38822532,
#        172.39331722, 173.38889647, 174.39414024, 175.38924193,
#        176.39458346, 177.39010382, 178.39521909, 179.39079332,
#        180.39608335, 181.39141631, 182.3965807 , 183.39206696,
#        184.39738441, 185.39275813, 186.39806461, 187.39336109,
#        188.38871455, 189.39399505, 190.38932467, 191.39442229,
#        192.38979888, 193.39529228, 194.3904357 , 195.39592505,
#        196.39103675, 197.39638186, 198.39178395, 199.39701867,
#        200.39244175, 201.3977356 , 202.39296341, 203.388309  ,
#        204.393641  , 205.38898468, 206.39442563, 207.38977432,
#        208.3951385 , 209.39049649, 210.43588376])

# %%
det.shape
# Out:
# (195, 2162, 2068)

# %%
images = det[:,:,:]
frames = np.arange(1,len(images))[:]

# %%
fig, ax = plt.subplots()
v = [1,5000] 
# YOUR CODE HERE
make_detector_movie(det[:,:,:]+1, time[:], fig, ax, file_list[1][:-3], (v[0],v[1]), fps=4,period=1)
# Out:
# <img src="data:image/png;base64,..." width="640">
