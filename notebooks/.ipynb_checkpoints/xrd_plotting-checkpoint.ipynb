# %%
import sys
sys.path.append('../src/')
from xpcs import *
from sims import *
from autocorrelations import *
import cv2
from scipy.special import erfinv
import pyopencl as cl

# %matplotlib notebook

# %%
path = '/Users/eriklamb/Documents/Data/XRD/'

file = 'NBH/mo_JB_NBH_03_0001.txt'
file2 = 'Sulfides_XRD/Na3PS4_cubic.txt'

xrd1 = np.loadtxt(path+file)
xrd2 = np.loadtxt(path+file2)

# %%
fig, ax = plt.subplots()

#ax.plot(xrd[:,0],xrd[:,1],'b',label="Mo")
ax.plot(th2q(15,newtth('Mo',15,xrd1[:,0])),xrd1[:,1],'r',label="NBH")
ax.plot(th2q(15,newtth('Mo',15,xrd2[:,0])),xrd2[:,1],'b',label="NPS")
ax.set_xlabel('Q (1/Å)')
ax.legend()
ax.set_title('NBH Mixed')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'NBH Mixed')

# %%
fig, ax = plt.subplots()

#ax.plot(xrd[:,0],xrd[:,1],'b',label="Mo")
ax.plot(newtth('Mo',15,xrd1[:,0]),xrd1[:,1],'r',label="NBH")
ax.plot(newtth('Mo',15,xrd2[:,0]),xrd2[:,1],'b',label="NPS")
ax.set_xlabel('Q (1/Å)')
ax.legend()
ax.set_title('NBH Mixed')
# Out:
# <img src="data:image/png;base64,..." width="855">
# Text(0.5, 1.0, 'NBH Mixed')
