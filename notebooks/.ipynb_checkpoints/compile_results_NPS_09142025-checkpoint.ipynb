# %%
import sys
sys.path.append('../src/')
from xpcs import *
from sims import *
from plotting import *
from autocorrelations import *
import cv2
from scipy.special import erfinv
import pyopencl as cl
from pathlib import Path
import json
from scipy.fft import fft, ifft, fftfreq

# %matplotlib notebook

# %%
### User Defined
### This should be the only thing that needs to defined
CONFIG_FILE_NAME = "config_NPS_2_data_090825.json" #"config_B10_2_A7_data_071525.json"

### Scan In Config You Want to PreProcess ### 
Scans = np.array([219,334,552,579,709,779,796,868])

# %% [markdown]
# # Extract Data

# %%
config_file = Path('/Users/eriklamb/Documents/Python/Projects/XPCS/configs/'+CONFIG_FILE_NAME)

# Open and load the JSON configuration file
with open(config_file, "r") as file:
    config = json.load(file)
    

for i,s in enumerate(Scans):
### Open Config File ###
# Define the path to the configuration file


    ### Load Work Paths ###
    BASE_DIR       = Path(config.get("Base"))
    dataset_path   = Path(config.get(f"{s}"))
    work_path      = BASE_DIR / dataset_path 
    processed_path = work_path / Path(config.get("Processed")) / Path(config.get(f"{s}_processed"))
    results_path   = work_path / Path(config.get("Results")) / Path(config.get(f"{s}_results"))



    ### Import Beamline Parameters ###
    ### Not user defined ###

    #Temperature Handled Differently Depending on Source 
    if 'B10' in Compound:
        Temperature = float(str(dataset_path)[21:27])/1000 #Temperature in Kelvin
    if 'NPS' in Compound:
        Temperature = float(config.get(f"{s}_temperature")) #Temperature in Kelvin

    #Check that the processed file exists
    if not os.path.exists(results_path):
        print(f"File '{results_path}' does not exist! Please create it in xpcs_1.")

    #Load file
    with h5py.File(results_path, 'r') as DATA:

        g2s    = DATA['XPCS/G2_Results'][:]
        g2Err  = DATA['XPCS/G2_error'][:]
        delays = DATA['XPCS/delays'][:][0]
        
    if i==0:
        
        G2S      = np.zeros((Scans.shape[0],g2s.shape[0],g2s.shape[1]))
        G2SErr   = np.zeros((Scans.shape[0],g2sErr.shape[0],g2sErr.shape[1]))
        #TWOTIMES = np.zeros((Scans.shape[0],g2sErr.shape[0],g2sErr.shape[1]))
        TEMPS    = np.zeros((1,Scans.shape[0]))
   
    G2S[i,:,:]    = g2s
    G2SERR[i,:,:] = g2Err
    TEMPS[0,i]    = int(Temperature)
# Out:
# Directory found: /Users/eriklamb/Documents/Data/PETRA/PETRA_P10_November2023/Beamtime_11017686/raw/NPS_01_00219/e4m
# Contains:
# NPS_01_00219.batchinfo
# NPS_01_00219_data_000001.h5
# NPS_01_00219_master.h5
# mask219.mat
# processed
# results

# %%
#Set the path to the processed file 
#processed = processed_path+f'particle{Particle}_temp{Temperature}K_scan{Scan}_crop{Xv}x{Xh}.h5'

#Check that the processed file exists
if not os.path.exists(results_path):
    print(f"File '{results_path}' does not exist! Please create it in xpcs_1.")

#Load file
with h5py.File(results_path, 'r') as DATA:
    
    g2s    = DATA['XPCS/G2_Results'][:]
    g2Err  = DATA['XPCS/G2_error'][:][0]
    delays = DATA['XPCS/delays'][:][0]

# %% [markdown]
# # G2s

# %%
fig,ax = plt.subplots(figsize=(16,10))

color_list = np.array(['red','blue','gray','orange','magenta','black','green','purple'])
marker_list = np.array(['v','s','o','*','p','D','>','H'])
i=0

popt,pcov = curve_fit(g2_exp,delays,g2s[0,:],p0=[1,50,2])

plot_g2s(ax,delays,(g2s[0,:]-1)/popt[0],(g2_exp(delays,*popt)-1)/popt[0],'298K',marker_list[i],color_list[i])
# Out:
# <img src="data:image/png;base64,..." width="1600">
