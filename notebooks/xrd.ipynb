# %%
import sys
sys.path.append('../src/')
from xpcs import *
from sims import *
from autocorrelations import *
import cv2
from scipy.special import erfinv
import pyopencl as cl

# %matplotlib notebook
# Out:
# python(2831) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
nps_bm_path = "/Users/eriklamb/Documents/Data/XRD/Calculated/na3ps4_bm_cubic.xy"
nps_tet_path = "/Users/eriklamb/Documents/Data/XRD/Calculated/na3ps4_tetragonal.xy"

# %%
bm = np.loadtxt(nps_bm_path)
tet = np.loadtxt(nps_tet_path)

# %%
bm.shape
# Out:
# (11900, 3)

# %%
fig, ax = plt.subplots()

ax.plot(th2q(14,bm[1200:4000,0]),bm[1200:4000,1]/bm.max(),'b',label='BM-Cubic')
ax.plot(th2q(14,tet[1200:4000,0]),tet[1200:4000,1]/bm.max(),'r',label='HT-Tetragonal')
ax.set_title('Ball-Milled Cubic', fontsize=14)
ax.set_title('Na3PS4', fontsize=18)
ax.set_yticks([])
ax.set_ylabel('Int (Arb. Units)',fontsize=14)
ax.set_xlabel('Q (1/Å)',fontsize=14)
ax.legend(fontsize=14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()

ax.plot(bm[:7000,0],bm[:7000,1],'b',label='Ball-Milled Cubic')
ax.plot(tet[:7000,0],tet[:7000,1],'r',label='Heat Treated 500C Tetragonal')
ax.set_title('Na$_3$PS$_4$', fontsize=16)
ax.set_xlabel('2$\\theta$')
ax.set_ylabel('Intensity (arb. units)')

ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="945">
